# %%
# %pip install alpaca-trade-api   #changed ! to %
# %pip install alpaca-py
# %pip install pandas_market_calendars   
# %pip install twelvedata
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#changed': Expected package name at the start of dependency specifier
#     #changed
#     ^
# Requirement already satisfied: alpaca-py in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.31.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alpaca-py) (1.1.0)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alpaca-py) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alpaca-py) (2.9.2)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alpaca-py) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alpaca-py) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alpaca-py) (13.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.3->alpaca-py) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.3->alpaca-py) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.3->alpaca-py) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.3->alpaca-py) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (2024.7.4)
# Requirement already satisfied: six>=1.5 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->alpaca-py) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas_market_calendars in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.4.1)
# Requirement already satisfied: pandas>=1.1 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas_market_calendars) (2.2.2)
# Requirement already satisfied: pytz in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas_market_calendars) (2024.1)
# Requirement already satisfied: python-dateutil in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas_market_calendars) (2.9.0.post0)
# Requirement already satisfied: exchange-calendars>=3.3 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas_market_calendars) (4.5.6)
# Requirement already satisfied: numpy in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from exchange-calendars>=3.3->pandas_market_calendars) (1.26.4)
# Requirement already satisfied: pyluach in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from exchange-calendars>=3.3->pandas_market_calendars) (2.2.0)
# Requirement already satisfied: toolz in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from exchange-calendars>=3.3->pandas_market_calendars) (1.0.0)
# Requirement already satisfied: tzdata in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from exchange-calendars>=3.3->pandas_market_calendars) (2024.1)
# Requirement already satisfied: korean-lunar-calendar in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from exchange-calendars>=3.3->pandas_market_calendars) (0.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil->pandas_market_calendars) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: twelvedata in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.24)
# Requirement already satisfied: pytimeparse<2,>=1.1 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from twelvedata) (1.1.8)
# Requirement already satisfied: requests<3,>=2.22 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from twelvedata) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.22->twelvedata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.22->twelvedata) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.22->twelvedata) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\irtho\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.22->twelvedata) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import pandas_market_calendars as mcal
from datetime import datetime
import time
import csv

from alpaca.data import StockHistoricalDataClient, TimeFrame
from alpaca.data.requests import StockBarsRequest

# %%
'''Connecting to Alpaca API here'''

path = "../../API_Keys/Alpaca_Keys.csv"

with open(path, mode='r', newline='') as file:
    csv_reader = csv.reader(file)
    API_KEY = next(csv_reader)[0]
    ALPACA_API_SECRET_KEY = next(csv_reader)[0]
    #TWELVE_DATA_KEY = next(csv_reader)[0]
    

data_client = StockHistoricalDataClient(API_KEY, ALPACA_API_SECRET_KEY)

# %%
'''Functions'''

def trading_days(end_d, days_back):
    nyse = mcal.get_calendar('NYSE')
    schedule = nyse.schedule(start_date=end_d - pd.Timedelta(days=days_back), end_date=end_d)
    td = schedule.index[0 : days_back] 
    return td



def call(start_date, stock, trading_days, percent_change):
    request_params = StockBarsRequest(
        symbol_or_symbols=[stock],            
        timeframe=TimeFrame.Day,
        start=start_date
    )

    # Fetch the bars data
    bars_data = data_client.get_stock_bars(request_params)
    bars_df = bars_data.df
    
    # Reset the index to separate the columns
    bars_df = bars_df.reset_index()

    # Convert the timezone of the timestamp column
    bars_df['timestamp'] = bars_df['timestamp'].dt.tz_convert('America/New_York')

    # Set the index back to symbol and timestamp if needed
    bars_df = bars_df.set_index(['symbol', 'timestamp'])

    #percent_change = [[0, 0] for i in range(len(trading_days))]
    for i in range(len(trading_days)):
        specific_date = pd.to_datetime(trading_days[i]).tz_localize('America/New_York')
        #print(specific_date)
        open_price = bars_df.loc[(stock, specific_date), 'open']
        close_price = bars_df.loc[(stock, specific_date), 'close']
        #percent_change[i][0] = f"{specific_date.date()} "
        #percent_change[i][1] = ((close_price/open_price)-1)*100
        percent_change.insert(0, [f"{specific_date.date()} ", ((close_price/open_price)-1)*100])
    return percent_change



def store_data(stock, percent_change):
    file_path = "Stocks/"+str(stock)+".csv"
    with open(file_path, mode='w', newline='') as file:   # w for a overwrite? 
        writer = csv.writer(file)
        writer.writerows(percent_change)
        
def add_ending(stock):
    file_path = "Stocks/"+str(stock)+".csv"
    with open(file_path, mode='a', newline='') as file:   # w for a overwrite? 
        writer = csv.writer(file)
        var = "end"
        writer.writerow(["--","--"])
        
        
def create_data(stock, days_back):
    #break up days back into unders 150s calls
    today = pd.Timestamp.today(tz='America/New_York').normalize()
    percent_change = []
    
    count = days_back
    
    while(True):
        if count >= 200:
            td= trading_days(today - pd.Timedelta(days=count-200), 200) # start and end dates
            start_date = today - pd.Timedelta(days=count)
            call(start_date, stock, td, percent_change)
            count -= 200
            #print(f"1' delay at {count}")
           # time.sleep(60)
        else: 
            td= trading_days(today, count)
            start_date = today - pd.Timedelta(days=count)
            call(start_date, stock, td, percent_change)
            break
    store_data(stock, percent_change)
    add_ending(stock)

# %%
''' Setting the days back '''

"""Bug to fix the days are required to be certain numbers and not others find out why and fix trading days only? """
int = 1000
while(True):
    try:
        create_data("SPY", int)  
        print(int)
        break
    except:
        int+=1
        print(int)
        
print("spy done")
# create_data("AMD", 50) 
# print("both good")
# Out:
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131

# %%
import csv


# Read the CSV file
def format_Data(name):
    # write a try condiiton here for catcing incorrect names
    data = []
    with open("../Stocks/"+str(name).upper()+".csv", 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            # Append each row to the data list
            date = row[0].strip()
            try:                                    # this is only here becuase of the closing --,-- causing errors
                value = float(row[1].strip())
                data.append([date, value])
            except:
                pass
            data.append([date, value])
    return data

# Now data is a 2D array ready for graphing
# SPY_Data = format_Data("SPY")
# print(SPY_Data)
AMD_Data = format_Data("AMD")
print(AMD_Data)
# Out:
# [['2024-10-11', 2.2566007856990478], ['2024-10-11', 2.2566007856990478], ['2024-10-10', -3.286993402450511], ['2024-10-10', -3.286993402450511], ['2024-10-09', -1.7408790577420286], ['2024-10-09', -1.7408790577420286], ['2024-10-08', 0.6113537117903967], ['2024-10-08', 0.6113537117903967], ['2024-10-07', -0.0642974047229461], ['2024-10-07', -0.0642974047229461], ['2024-10-04', 2.62230308707585], ['2024-10-04', 2.62230308707585], ['2024-10-03', 1.9660634900757534], ['2024-10-03', 1.9660634900757534], ['2024-10-02', 0.2950222835980121], ['2024-10-02', 0.2950222835980121], ['2024-10-01', -2.875729571984431], ['2024-10-01', -2.875729571984431], ['2024-09-30', 0.6008583690987335], ['2024-09-30', 0.6008583690987335], ['2024-09-27', -1.8688798662526818], ['2024-09-27', -1.8688798662526818], ['2024-09-26', 0.2603932836491074], ['2024-09-26', 0.2603932836491074], ['2024-09-25', 2.220820189274453], ['2024-09-25', 2.220820189274453], ['2024-
# %%
import matplotlib.pyplot as plt

def graph(stock, percent_change):
    '''graph the daily % changes'''
    days = len(percent_change)
    x = range(days)

    y = [percent[1] for percent in percent_change]

    # Determine colors for positive and negative changes
    colors = ['green' if value > 0 else 'red' for value in y]

    # Create a bar plot with the specified colors
    plt.bar(x, y, color=colors, label=stock + " Data")

    # Add title and labels
    plt.title(f'{stock} Daily Percent Change')
    plt.xlabel('Days')
    plt.ylabel('% Change')

    # Add a legend
    plt.legend()
    plt.axhline(y=0, color='gray', linestyle='--')

    # Display the plot
    plt.show()

# Example data
graph('AMD', data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 29
#      26     plt.show()
#      28 # Example data
# ---> 29 graph('AMD', AMD_Data)
#
# NameError: name 'AMD_Data' is not defined

# %%
def calculate_transition_probabilities(data):
    # Initialize counters
    pos_to_pos = 0
    pos_to_neg = 0
    neg_to_pos = 0
    neg_to_neg = 0
    
    # Iterate through the data to count transitions
    for i in range(len(data) - 1):
        current_day = data[i][1]
        next_day = data[i + 1][1]
        
        if current_day > 0 and next_day > 0:
            pos_to_pos += 1
        elif current_day > 0 and next_day <= 0:
            pos_to_neg += 1
        elif current_day <= 0 and next_day > 0:
            neg_to_pos += 1
        elif current_day <= 0 and next_day <= 0:
            neg_to_neg += 1
    
    # Calculate total transitions from positive and negative days
    total_pos = pos_to_pos + pos_to_neg
    total_neg = neg_to_pos + neg_to_neg
    
    # Calculate probabilities
    prob_pos_to_pos = pos_to_pos / total_pos if total_pos > 0 else 0
    prob_pos_to_neg = pos_to_neg / total_pos if total_pos > 0 else 0
    prob_neg_to_pos = neg_to_pos / total_neg if total_neg > 0 else 0
    prob_neg_to_neg = neg_to_neg / total_neg if total_neg > 0 else 0
    
    # Construct the transition probability matrix
    transition_matrix = [
        [prob_pos_to_pos, prob_pos_to_neg],  # From positive day
        [prob_neg_to_pos, prob_neg_to_neg]   # From negative day
    ]
    
    return transition_matrix

# Example data
graph = calculate_transition_probabilities(AMD_Data)

print(f"p-p: {graph[0][0]},   p-n: {graph[0][1]},    n-p: {graph[1][0]},  n-n: {graph[1][1]}")
# Out:
# p-p: 0.748062015503876,   p-n: 0.25193798449612403,    n-p: 0.25523560209424084,  n-n: 0.7447643979057592

# %%
from twelvedata import TDClient

# Initialize client - apikey parameter is requiered
td = TDClient(apikey=TWELVE_DATA_KEY)

# Construct the necessary time series
ts = td.time_series(
    symbol="AAPL",
    interval="1day",
    outputsize=1,
    timezone="America/New_York",
)
  
# Returns pandas.DataFrame
ts.as_pandas()
# Out:
#                  open    high    low      close    volume
# datetime
# 2024-06-14  213.85001  215.17  211.3  212.49001  69175600
